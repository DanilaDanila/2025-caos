# %%
# !jupyter nbconvert epoll.ipynb --to slides --post serve
# Out:
# [NbConvertApp] Converting notebook epoll.ipynb to slides
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 481467 bytes to epoll.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Serving your slides at http://127.0.0.1:8000/epoll.slides.html
# Use Control-C to stop this server
# 404 GET /favicon.ico (127.0.0.1) 0.61ms
# ^C
#
# Interrupted

# %% [markdown]
# # Сети - 2

# %% [markdown]
# # ~~Сети - 2~~
# # 10k problem

# %% [markdown]
# ## 10k problem
#
# У нас есть веб сервер
#
# Как выжать из него максимум?

# %% [markdown]
# # do nothing

# %% [markdown]
# is always an option

# %% [markdown]
# # do nothing x2

# %% [markdown]
# давайте запустим второй процесс рядом)

# %% [markdown]
# # fork()

# %% [markdown]
# Идея: давайте на каждого клиента создавать процесс

# %% [markdown]
# (примерно так делает Apache web server)

# %% [markdown]
# # pthread_create()

# %% [markdown]
# Относительно fork() прирост будет незначительный, но системе будет "легче" плодить потоки

# %% [markdown]
# # асинхронность

# %% [markdown]
# <img src="data:image/png;base64,...">

# %% [markdown]
# # epoll()

# %% [markdown]
# примерно так делает Nginx / Node / FastAPI / ...

# %% [markdown]
# # poll()

# %% [markdown]
# # kqueue()

# %% [markdown]
# # Хвала!
