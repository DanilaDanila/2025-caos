# %%
# !jupyter nbconvert dynamic.ipynb --to slides --post serve
# Out:
# [NbConvertApp] Converting notebook dynamic.ipynb to slides
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 406019 bytes to dynamic.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Serving your slides at http://127.0.0.1:8000/dynamic.slides.html
# Use Control-C to stop this server
# 404 GET /favicon.ico (127.0.0.1) 0.96ms

# %% [markdown]
# # Динамическая линковка

# %% [markdown]
# # Recap: этапы сборки

# %% [markdown]
# <img src="data:image/jpeg;base64,..." />

# %% [markdown]
# - Препроцессор
#   - из кода на C делает код на C

# %% [markdown]
# - Компилятор
#   - из кода на С делает промежуточное представление (ASM / llvm)

# %% [markdown]
# - Ассемблер
#   - из кода на ASM делает машинные инструкции

# %% [markdown]
# - Линкер
#   - собирает разные `.o` файлы вместе
#   - высчитывает адреса функций
#   - высчитывает адреса библиотек (статических и динамических)

# %% [markdown]
# # Что происходит дальше

# %% [markdown]
# ## Вы запускаете и оно работает

# %% [markdown]
# ## ~~Вы запускаете и оно работает~~

# %% [markdown]
# ## ~~Вы запускаете и оно работает~~
# ## Вы запускаете и оно подтягивает зависимости

# %% [markdown]
# - mmap

# %% [markdown]
# ## Где хранятся зависимости?

# %% [markdown]
# - `objdump`

# %% [markdown]
# - `ldd`

# %% [markdown]
# # А в чем разница?

# %% [markdown]
# # Давайте напишем что-нибудь свое и прилинкуем динамически

# %% [markdown]
# ## Флаги компилятора

# %% [markdown]
# - `-l`

# %% [markdown]
# - `-I`

# %% [markdown]
# - `-L`

# %% [markdown]
# ## А где он ищет `.so` во время запуска?)

# %% [markdown]
# # dlfcn

# %% [markdown]
# # Python C API

# %% [markdown]
# # Сау болыңыз
